# %% [markdown]
# Importing Libaraies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing Dataset

# %%
data= pd.read_csv('/content/hotel_bookings.csv')

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.tail()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 51385  City Hotel            1        316               2016
# 51386  City Hotel            1        316               2016
# 51387  City Hotel            1         28               2016
# 51388  City Hotel            1        316               2016
# 51389  City Hotel            1        316               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 51385                May                        21                         19
# 51386                May                        21                         19
# 51387                May                        21                         19
# 51388                May                        21                         19
# 51389                May                        21                         19
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %% [markdown]
# Analyising and Cleaning the Data

# %%
data.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
data.tail(10)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 51380  City Hotel            1        316               2016
# 51381  City Hotel            1        316               2016
# 51382  City Hotel            1        316               2016
# 51383  City Hotel            1         28               2016
# 51384  City Hotel            1        316               2016
# 51385  City Hotel            1        316               2016
# 51386  City Hotel            1        316               2016
# 51387  City Hotel            1         28               2016
# 51388  City Hotel            1        316               2016
# 51389  City Hotel            1        316               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 51380                May                        21                         19
# 51381                May                        21                         19
# ...

# %%
data.shape
# Out:
# (51390, 32)
